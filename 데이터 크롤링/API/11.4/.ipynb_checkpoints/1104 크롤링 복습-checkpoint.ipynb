# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import numpy as np

# %%
url='http://apis.data.go.kr/openapi/service/ElevatorInformationService/getElevatorList'
serviceKey='rbQTU+viLPcb7BcVL3aUQ2gVVsybou+1wcnQaZ0a3xSuuRG8y/6yNTnuK/ihWqAD0Wehz12RfZscFpSjzANRTw=='
numOfRows='20'
pageNo='2'
sido='서울특별시'
sigungu='강남구'

# %%
params={'serviceKey':serviceKey,'numOfRows':numOfRows,'pageNo':pageNo,'sido':sido,'sigungu':sigungu}

# %%
req=requests.get(url, params=params,verify=False)

# %%
req.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><address1>서울특별시 강남구 논현로85길 23</address1><address2>(역삼동)</address2><applcBeDt>2022-04-29</applcBeDt><applcEnDt>2023-04-28</applcEnDt><areaNo>01</areaNo><buldMgtNo1>135</buldMgtNo1><buldMgtNo2>471</buldMgtNo2><buldNm>(재)이스테파노</buldNm><buldPrpos>제2종근린생활시설-기타</buldPrpos><divGroundFloorCnt>8</divGroundFloorCnt><divUndgrndFloorCnt>2</divUndgrndFloorCnt><elevatorNo>0076991</elevatorNo><elvtrAsignNo>1</elvtrAsignNo><elvtrDivNm>엘리베이터</elvtrDivNm><elvtrFormNm>권상식-VVVF</elvtrFormNm><elvtrKindNm>승객용</elvtrKindNm><elvtrMgtNo1>135</elvtrMgtNo1><elvtrMgtNo2>1077</elvtrMgtNo2><elvtrModel>ACD5MRGM1(M)</elvtrModel><elvtrResmptDe>--</elvtrResmptDe><elvtrStts>운행중</elvtrStts><frstInstallationDe>1995-11-18</frstInstallationDe><inspctInstt>한국승강기안전공단 서울강남지사</inspctInstt><installationDe>2021-04-29</installationDe><installationPlace>1-1</install
# ...

# %%
soup=BeautifulSoup(req.text,'xml')

# %%
soup.text
# Out:
# '00NORMAL SERVICE.서울특별시 강남구 논현로85길 23(역삼동)2022-04-292023-04-2801135471(재)이스테파노제2종근린생활시설-기타8200769911엘리베이터권상식-VVVF승객용1351077ACD5MRGM1(M)--운행중1995-11-18한국승강기안전공단 서울강남지사2021-04-291-12022-06-27정기조건부합격900 KG오티스엘리베이터(유)서울02-2007-5800919920075920180033오티스엘리베이터(유)강남지사02-2007-5800Y김영국010-8746-6***---12 인승1 M/MIN10선임(운행관리자정보없음)-B2-81353-06237서울특별시 강남구 논현로85길 23(역삼동)2022-05-272022-11-2601135471(재)이스테파노제2종근린생활시설-기타8200769922엘리베이터유압식-교류자동차용1351078확인불가--운행중1995-11-18한국승강기안전공단 서울강남지사1995-11-181-22022-06-27정기합격2000 KG동국산전(주)031-989-4190919920080919920130(주)카이로스리프트02-2691-4771Y김영국010-8746-6***---.38 M/MIN2선임(운행관리자정보없음)-B2-B113520-06237서울특별시 강남구 테헤란로98길 16(대치동)2021-11-102022-11-09011352015(재)제주장학재단제2종근린생활시설-기타8200673371엘리베이터권상식-VVVF승객용1357028WBLX-GA-1(M)--운행중1985-10-17한국승강기안전공단 서울강남지사2021-11-101-12021-11-10설치합격700 KG현대엘리베이터(주)043-722-1000919920035920180024현대엘리베이터(주)강남지사02-6953-6213Y양수철(02)555-1***---9 인승1.5 M/MIN10선임(운행관리자정보없음)-B2-81353-06181서울특별시 강남구 언주로148길 14(논현동)2022-09-082023-09-07011352605(재)청호불
# ...

# %%
col_list=['address1','address2','buldNm','elevatorNo','elvtrStts','lastInspctDe','liveLoad','manufacturerTelno']

# %%
req.url
# Out:
# 'http://apis.data.go.kr/openapi/service/ElevatorInformationService/getElevatorList?serviceKey=rbQTU%2BviLPcb7BcVL3aUQ2gVVsybou%2B1wcnQaZ0a3xSuuRG8y%2F6yNTnuK%2FihWqAD0Wehz12RfZscFpSjzANRTw%3D%3D&numOfRows=20&pageNo=2&sido=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C&sigungu=%EA%B0%95%EB%82%A8%EA%B5%AC'

# %%
data=[]
for col in col_list:
    temp=[]
    for d in soup.select(col):
        temp.append(d.text)
    data.append(temp)

# %%
data
# Out:
# [['서울특별시 강남구 논현로85길 23',
#   '서울특별시 강남구 논현로85길 23',
#   '서울특별시 강남구 테헤란로98길 16',
#   '서울특별시 강남구 언주로148길 14',
#   '서울특별시 강남구 언주로148길 14',
#   '서울특별시 강남구 테헤란로 211',
#   '서울특별시 강남구 테헤란로 211',
#   '서울특별시 강남구 테헤란로 211',
#   '서울특별시 강남구 테헤란로 211',
#   '서울특별시 강남구 선릉로146길 56',
#   '서울특별시 강남구 도산대로16길 13-5',
#   '서울특별시 강남구 광평로47길 28',
#   '서울특별시 강남구 언주로 517',
#   '서울특별시 강남구 언주로 517',
#   '서울특별시 강남구 언주로 517',
#   '서울특별시 강남구 도산대로 443',
#   '서울특별시 강남구 압구정로 429',
#   '서울특별시 강남구 압구정로 429',
#   '서울특별시 강남구 테헤란로 321',
#   '서울특별시 강남구 테헤란로 321'],
#  ['(역삼동)',
#   '(역삼동)',
#   '(대치동)',
#   '(논현동)',
#   '(논현동)',
#   '(역삼동)',
#   '(역삼동)',
#   '(역삼동)',
#   '(역삼동)',
#   '(청담동)',
#   '(논현동)',
#   '(수서동)',
#   '(역삼동)',
#   '(역삼동)',
#   '(역삼동)',
#   '(청담동)',
#   '(청담동)',
#   '(청담동)',
#   '(역삼동)',
#   '(역삼동)'],
#  ['(재)이스테파노',
#   '(재)이스테파노',
#   '(재)제주장학재단',
#   '(재)청호불교문화원',
#   '(재)청호불교문화원',
#   '(재)한국고등교육재단',
#   '(재)한국고등교육재단',
#   '(재)한국고등교육재단',
#   '(재)한국고등교육재단',
#   '(주)GBSTYLE제니하우스',
#   '(주)JMPLUSS',
# ...

# %%
data=pd.DataFrame(data)

# %%
data
# Out:
#                     0                    1                     2   \
# 0  서울특별시 강남구 논현로85길 23  서울특별시 강남구 논현로85길 23  서울특별시 강남구 테헤란로98길 16
# 1                (역삼동)                (역삼동)                 (대치동)
# 2             (재)이스테파노             (재)이스테파노             (재)제주장학재단
# 3              0076991              0076992               0067337
# 4                  운행중                  운행중                   운행중
# 5           2022-06-27           2022-06-27            2021-11-10
# 6               900 KG              2000 KG                700 KG
# 7         02-2007-5800         031-989-4190          043-722-1000
#
#                      3                     4                   5   \
# 0  서울특별시 강남구 언주로148길 14  서울특별시 강남구 언주로148길 14  서울특별시 강남구 테헤란로 211
# 1                 (논현동)                 (논현동)               (역삼동)
# 2            (재)청호불교문화원            (재)청호불교문화원         (재)한국고등교육재단
# 3               0066956               0066957             0079198
# ...

# %%
soup.select(col)
# Out:
# [<manufacturerTelno>02-2007-5800</manufacturerTelno>,
#  <manufacturerTelno>031-989-4190</manufacturerTelno>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <manufacturerTelno>055-269-4114</manufacturerTelno>,
#  <manufacturerTelno>031-233-4992</manufacturerTelno>,
#  <manufacturerTelno>031-233-4992</manufacturerTelno>,
#  <manufacturerTelno>031-233-4992</manufacturerTelno>,
#  <manufacturerTelno>031-233-4992</manufacturerTelno>,
#  <manufacturerTelno>02-2007-5800</manufacturerTelno>,
#  <manufacturerTelno>043-722-1000</manufacturerTelno>,
#  <manufacturerTelno>02-2610-7869</manufacturerTelno>,
#  <manufacturerTelno>02-2610-7869</manufacturerTelno>,
#  <manufacturerTelno>02-2610-7869</manufacturerTelno>,
#  <manufacturerTelno>02-2610-7869</manufacturerTelno>,
#  <manufacturerTelno>02-2610-7869</manufacturerTelno>,
#  <manufacturerTelno>055-269-4114</manufacturerTelno>,
# ...

# %%
url='https://www.imdb.com/chart/boxoffice/?ref_=nv_ch_cht'

# %%
req=requests.get(url)

# %%
req.text
# Out:
# '\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n\n        <meta charset="utf-8">\n\n    \n    \n    \n\n    \n    \n    \n\n            <style>\n                body#styleguide-v2 {\n                    background: no-repeat fixed center top #000;\n                }\n            </style>\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb Top Box Office - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }
# ...

# %%
html=req.text

# %%
soup2=BeautifulSoup(html,'html.parser')

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb Top Box Office - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
# ...

# %%
title=soup2.select('#boxoffice > table > tbody > tr:nth-child(1)>td>td>a' )

# %%
title[0].text
# Out:
# 'Black Adam'

# %%
title[0].text
# Out:
# 'Black Adam'

# %%
soup2.select('#boxoffice > table > tbody > tr:nth-child(2) > td>td>a')
# Out:
# [<a href="/title/tt14109724" title="Ol Parker (dir.), George Clooney, Sean Lynch">Ticket to Paradise</a>]

# %%
title2=soup2.select('#boxoffice > table > tbody > tr:nth-child(2) > td>td>a')

# %%
title2[0].text
# Out:
# 'Ticket to Paradise'

# %%
title3=soup2.select('#boxoffice > table > tbody > tr:nth-child(3) > td>td>a')

# %%
title4=soup2.select('#boxoffice > table > tbody > tr:nth-child(4) > td>td>a')

# %% [markdown]
# -----------------

# %%
title=soup2.select('#boxoffice > table > tbody > tr > td>td.titleColumn>a')

# %%
data=[]
for t in title:
    temp=[]
    temp.append(t.text)
    temp.append(t['href'].replace('/title/',''))
    data.append(temp)

# %%
title[0]
# Out:
# <a href="/title/tt6443346" title="Jaume Collet-Serra (dir.), Dwayne Johnson, Aldis Hodge">Black Adam</a>

# %%
title[0]['href']
# Out:
# '/title/tt6443346'

# %%
title[0]['href'].replace('/title/','')
# Out:
# 'tt6443346'

# %%
data
# Out:
# [['Black Adam', 'tt6443346'],
#  ['Ticket to Paradise', 'tt14109724'],
#  ['Prey for the Devil', 'tt9271672'],
#  ['Smile', 'tt15474916'],
#  ['Halloween Ends', 'tt10665342'],
#  ['Till', 'tt4960748'],
#  ['Lyle, Lyle, Crocodile', 'tt14668630'],
#  ['Terrifier 2', 'tt10403420'],
#  ['The Woman King', 'tt8093700'],
#  ['Tár', 'tt14444726']]

# %%
df=pd.DataFrame(data,columns=['movie','code'])

# %%
df
# Out:
#                    movie        code
# 0             Black Adam   tt6443346
# 1     Ticket to Paradise  tt14109724
# 2     Prey for the Devil   tt9271672
# 3                  Smile  tt15474916
# 4         Halloween Ends  tt10665342
# 5                   Till   tt4960748
# 6  Lyle, Lyle, Crocodile  tt14668630
# 7            Terrifier 2  tt10403420
# 8         The Woman King   tt8093700
# 9                    Tár  tt14444726

# %%
def soup_get(url):
    req=requests.get(url)
    soup=BeautifulSoup(req.text,'html.parser')
    return soup

# %%
url2='https://www.imdb.com/title/tt6443346/reviews?spoiler=hide&sort=curated&dir=desc&ratingFilter=0'

# %%
for code in df['code'][:2]:
    url2='https://www.imdb.com/title/'+ df['code'][0] + '/reviews?spoiler=hide&sort=curated&dir=desc&ratingFilter=0'
    soup=soup_get(url2)
    soup.select('#main > section > div.lister > div.lister-list > div:nth-child(1)')

# %%
url2='https://www.imdb.com/title/'+ df['code'][0] + '/reviews?spoiler=hide&sort=curated&dir=desc&ratingFilter=0'
soup=soup_get(url2)
review=soup.select('#main > section > div.lister > div.lister-list > div:nth-child(1)')

# %%
review
# Out:
# [<div class="lister-item mode-detail imdb-user-review collapsable" data-review-id="rw8623676" data-vote-url="/title/tt6443346/review/rw8623676/vote/interesting">
#  <div class="review-container">
#  <div class="lister-item-content">
#  <div class="ipl-ratings-bar">
#  <span class="rating-other-user-rating">
#  <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  <span>8</span><span class="point-scale">/10</span>
#  </span>
#  </div>
#  <a class="title" href="/review/rw8623676/"> Black Adam Is Not Perfect But It's Still Great, It's Still Fun, It's Still Fascinating, It's Still Exciting, And I Enjoy The Hell Out Of It
#  </a> <div class="display-name-date">
# ...

# %%
review[0].find('a',{'class':'title'})
# Out:
# <a class="title" href="/review/rw8623676/"> Black Adam Is Not Perfect But It's Still Great, It's Still Fun, It's Still Fascinating, It's Still Exciting, And I Enjoy The Hell Out Of It
# </a>

# %%
review[0].find('a',{'class':'title'}).text.strip()
# Out:
# "Black Adam Is Not Perfect But It's Still Great, It's Still Fun, It's Still Fascinating, It's Still Exciting, And I Enjoy The Hell Out Of It"

# %%
review[0].find_all('a',{'class':'title'})[0]
# Out:
# <a class="title" href="/review/rw8623676/"> Black Adam Is Not Perfect But It's Still Great, It's Still Fun, It's Still Fascinating, It's Still Exciting, And I Enjoy The Hell Out Of It
# </a>

# %%
review[0]
# Out:
# <div class="lister-item mode-detail imdb-user-review collapsable" data-review-id="rw8623676" data-vote-url="/title/tt6443346/review/rw8623676/vote/interesting">
# <div class="review-container">
# <div class="lister-item-content">
# <div class="ipl-ratings-bar">
# <span class="rating-other-user-rating">
# <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M0 0h24v24H0z" fill="none"></path>
# <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
# <path d="M0 0h24v24H0z" fill="none"></path>
# </svg>
# <span>8</span><span class="point-scale">/10</span>
# </span>
# </div>
# <a class="title" href="/review/rw8623676/"> Black Adam Is Not Perfect But It's Still Great, It's Still Fun, It's Still Fascinating, It's Still Exciting, And I Enjoy The Hell Out Of It
# </a> <div class="display-name-date">
# ...

# %%
content=review[0].find('div',{'class':"text show-more__control"}).text.strip()

# %%
stars=review[0].find('span').text.strip().replace('/10','')

# %%
review[0].find('span',class_=False).text ##내장함수 _하면 변수로 쓸 수 있다.
###review[0].find('a',href=False).text
# Out:
# '8'

# %%
# <div class="lister-item mode-detail imdb-user-review collapsable" data-review-id="rw8623676" data-vote-url="/title/tt6443346/review/rw8623676/vote/interesting">
# <div class="review-container">
# <div class="lister-item-content">
# <div class="ipl-ratings-bar">
# <span class="rating-other-user-rating">
# <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M0 0h24v24H0z" fill="none"></path>
# <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
# <path d="M0 0h24v24H0z" fill="none"></path>
# </svg>
# <span>8</span><span class="point-scale">/10</span>
# </span>

# %%
for code in df['code'][:2]:
    url2='https://www.imdb.com/title/'+ df['code'][0] + '/reviews?spoiler=hide&sort=curated&dir=desc&ratingFilter=0'
    soup=soup_get(url2)
    soup.select('#main > section > div.lister > div.lister-list > div:nth-child(1)')

# %% [markdown]
#     review[0].find('a',{'class':'title'})
#     content=review[0].find('div',{'class':"text show-more__control"}).text.strip()
#     stars=review[0].find('span').text.strip().replace('/10','')
#     print(review)

# %%
len(df['code'])
# Out:
# 10

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>블랙 아담 (2022) - 블랙 아담 (2022) - User Reviews - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/title/tt6443346/reviews" rel="canonical"/>
# ...

# %%
data2=[]
for i in df['code']:
    url2='https://www.imdb.com/title/'+ i + '/reviews?spoiler=hide&sort=curated&dir=desc&ratingFilter=0'
    soup=soup_get(url2)
    review=soup.select('#main > section > div.lister > div.lister-list > div')
    for r in review:
        temp=[]
        temp.append(code)
        temp.append(r.find('a',{'class':'title'}).text.strip())
        temp.append(r.find('div',{'class':"text show-more__control"}).text.strip())
        try:
            temp.append(int(r.find('span',class_=False).text))
        except:
            temp.append(0)
    
        data2.append(temp)

# %%
df

# %%
len(data2)
# Out:
# 238

# %%
data2
# Out:
# [['tt14444726',
#   "Black Adam Is Not Perfect But It's Still Great, It's Still Fun, It's Still Fascinating, It's Still Exciting, And I Enjoy The Hell Out Of It",
# ...

# %%
df1=pd.DataFrame(data2, columns=['code','title','content','score'])

# %%
df1
# Out:
#            code                                              title  \
# 0    tt14444726  Black Adam Is Not Perfect But It's Still Great...
# 1    tt14444726            If Michael Bay & Zack Snyder had a baby
# 2    tt14444726                    Fast paced action and kinda fun
# 3    tt14444726                           It was surprisingly fun!
# 4    tt14444726  Never seen a movie so bad that I still enjoyed...
# ..          ...                                                ...
# 233  tt14444726  An intriguing film centered on a powerhouse pe...
# 234  tt14444726                               Blanchett is Genius!
# 235  tt14444726                                   Not for Everyone
# 236  tt14444726  Not an Easy Watch, but Effective and Engrossin...
# 237  tt14444726             A tiring and utterly forgettable movie
#
#                                                content  score
# 0    Black Adam is not without its flaws, but i sti...      8
# ...

# %%
df1['score'].unique()
####Was this review helpful? <a href="/registration/signin"> Sign in</a> to vote. 숫자가 아님
# Out:
# array([ 8,  7,  6,  5,  9,  3,  4,  1,  2, 10,  0], dtype=int64)

# %%
df1['score']
# Out:
# 0       8
# 1       7
# 2       7
# 3       8
# 4       6
#        ..
# 233     8
# 234    10
# 235     7
# 236     8
# 237     3
# Name: score, Length: 238, dtype: int64

# %%
df_all=pd.merge(df,df1,on='code')

# %%
df_all.drop(columns='code',inplace=True)

# %%
df_all
# Out:
#     movie                                              title  \
# 0     Tár  Black Adam Is Not Perfect But It's Still Great...
# 1     Tár            If Michael Bay & Zack Snyder had a baby
# 2     Tár                    Fast paced action and kinda fun
# 3     Tár                           It was surprisingly fun!
# 4     Tár  Never seen a movie so bad that I still enjoyed...
# ..    ...                                                ...
# 233   Tár  An intriguing film centered on a powerhouse pe...
# 234   Tár                               Blanchett is Genius!
# 235   Tár                                   Not for Everyone
# 236   Tár  Not an Easy Watch, but Effective and Engrossin...
# 237   Tár             A tiring and utterly forgettable movie
#
#                                                content  score
# 0    Black Adam is not without its flaws, but i sti...      8
# 1    Black Adam is the perfect example of how inacc...      7
# ...
